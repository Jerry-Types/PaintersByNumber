# %%
# http://scikit-image.org/docs/0.13.x/api/skimage.feature.html?highlight=hog#skimage.feature.hog
import matplotlib.pyplot as plt
from skimage.feature import hog
from skimage import data, color, exposure, io

# %%
# !ls Artist/Abanindranath_Tagore
# Out:
# 100446.jpg  1042.jpg  1651.jpg	18562.jpg

# %%
im = io.imread("Artist/Abanindranath_Tagore/1042.jpg")
image = color.rgb2gray(im)
fd, hog_image = hog(image, orientations=8, pixels_per_cell=(16,16),
                    cells_per_block=(1, 1), visualise=True)

print len(fd)
print len(hog_image)
# Out:
# 8960
# 460

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4), sharex=True, sharey=True)

ax1.axis('off')
ax1.imshow(image, cmap=plt.cm.gray)
ax1.set_title('Input image')
ax1.set_adjustable('box-forced')

# Rescale histogram for better display
hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 0.02))

ax2.axis('off')
ax2.imshow(hog_image_rescaled, cmap=plt.cm.gray)
ax2.set_title('Histogram of Oriented Gradients')
ax1.set_adjustable('box-forced')
plt.show()

# %%
import os, glob
import cv2
import numpy as np
import matplotlib.pyplot as plt
from skimage.feature import hog
from skimage import data, color, exposure, io

dir_list = next(os.walk('Artist/'))[1]

for dir_artis in dir_list:
    print ("Se va a procesar el artista :",dir_artis)
    images = [f for f in glob.glob("/home/nemis/Proyecto_Aprendizaje/Artist/"+dir_artis+"/*")]
    os.makedirs("Artist/"+dir_artis+"/features_HOG/")
    for img in images:
        print img
        im = io.imread(img)
        image = color.rgb2gray(im)
        fd, hog_image = hog(image, orientations=8, pixels_per_cell=(16,16),
                    cells_per_block=(1, 1), visualise=True)
        name=(img.split("/"))[-1]
        #print ('Artist/'+dir_artis+'/features/'+name+'.npy')
        np.save('Artist/'+dir_artis+'/features_HOG/'+name+'.npy', fd) 
    print ("Se ha procesado el artista :",dir_artis)
# Out:
# Henry_Raeburn
# /home/nemis/Proyecto_Aprendizaje/Artist/Henry_Raeburn/1671.jpg
# /home/nemis/Proyecto_Aprendizaje/Artist/Henry_Raeburn/11499.jpg
# /home/nemis/Proyecto_Aprendizaje/Artist/Henry_Raeburn/101065.jpg
# /home/nemis/Proyecto_Aprendizaje/Artist/Henry_Raeburn/13761.jpg
# /home/nemis/Proyecto_Aprendizaje/Artist/Henry_Raeburn/10878.jpg
# /home/nemis/Proyecto_Aprendizaje/Artist/Henry_Raeburn/12216.jpg
# /home/nemis/Proyecto_Aprendizaje/Artist/Henry_Raeburn/1040.jpg
# /home/nemis/Proyecto_Aprendizaje/Artist/Henry_Raeburn/13768.jpg
# /home/nemis/Proyecto_Aprendizaje/Artist/Henry_Raeburn/15983.jpg

# %%
  images = [f for f in glob.glob("/home/nemis/Proyecto_Aprendizaje/Artist/"+dir_artis+"/*")]
    #print (dir_artis)
    #print (images)
    os.makedirs("Artist/"+dir_artis+"/features/")
    for img in images :
        pic = cv2.imread(img)
        kp,desc = sift_features(pic)
        name=(img.split("/"))[-1]
        #print ('Artist/'+dir_artis+'/features/'+name+'.npy')
        np.save('Artist/'+dir_artis+'/features/'+name+'.npy', desc) 
    print (dir_artis+" se terminó de procesar")
    #break
